# %%
import pandas as pd
pd.set_option('display.width', 1000)
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
import requests

# %%
counties = pd.read_csv('../data/county_list.csv',encoding= 'unicode_escape')

# %%
counties.head(3)
# Out:
#                        county
# 0  Marshall County, Tennessee
# 1      Polk County, Tennessee
# 2     Wayne County, Tennessee

# %%
counties.shape
# Out:
# (95, 1)

# %%
county_list = counties['county'].tolist()
#Make dataframe to a list
len(county_list)
# Out:
# 95

# %%
API_KEY = pd.read_csv('../../api_key_work.txt', sep=" ", header=None).iloc[0,0]

# %%
#Pull geographic centers of each county from Google API
def get_google_results(address, api_key=None):

    geocode_url = "https://maps.googleapis.com/maps/api/geocode/json?address={}".format(address)
    if api_key is not None:
        geocode_url = geocode_url + "&key={}".format(api_key)
        
    results = requests.get(geocode_url)
    results = results.json()
    
    if len(results['results']) == 0:
        output = {
            "formatted_address" : None,
            "latitude": None,
            "longitude": None,
            "accuracy": None,
            "google_place_id": None,
            "type": None,
            "postcode": None
        }
    else:    
        answer = results['results'][0]
        output = {
            "formatted_address" : answer.get('formatted_address'),
            "latitude": answer.get('geometry').get('location').get('lat'),
            "longitude": answer.get('geometry').get('location').get('lng'),
            "location_type": answer.get('geometry').get('location_type'),
            "place_id": answer.get("place_id"),
            "types": ",".join(answer.get('types')),
            "partial_match" : answer.get('partial_match'),
            "postcode": ",".join([x['long_name'] for x in answer.get('address_components') 
                                  if 'postal_code' in x.get('types')])
        }
        
    # Append some other details:    
    output['input_string'] = address
    output['number_of_results'] = len(results['results'])
    output['status'] = results.get('status')
    
    return output

# %%
#Test!
geocode_result = get_google_results('str,hendersonville, tn', API_KEY)
geocode_result
# Out:
# {'formatted_address': '735 E Main St, Hendersonville, TN 37075, USA',
#  'latitude': 36.3268836,
#  'longitude': -86.5591469,
#  'location_type': 'ROOFTOP',
#  'place_id': 'ChIJ1dQmQ-s4ZIgRSqWf0GqNRuM',
#  'types': 'establishment,point_of_interest,travel_agency',
#  'partial_match': None,
#  'postcode': '37075',
#  'input_string': 'str,hendersonville, tn',
#  'number_of_results': 1,
#  'status': 'OK'}

# %%
len(county_list)
# Out:
# 95

# %%
results = []
for county in county_list:
    try:
        geocode_result = get_google_results(county, API_KEY)
    except:
        None
            
    results.append(geocode_result)           

    if len(results) % 5 == 0:
        pd.DataFrame(results).to_csv("{}_bak.csv".format('countyresults'), index = False)

pd.DataFrame(results)
# Out:
#                                     formatted_address   latitude  longitude location_type                     place_id                                  types partial_match postcode                  input_string  number_of_results status
# 0                            Marshall County, TN, USA  35.479252 -86.781852   APPROXIMATE  ChIJ57A-IJS7Y4gRoHylw8oHt-U  administrative_area_level_2,political          None             Marshall County, Tennessee                  1     OK
# 1                                Polk County, TN, USA  35.137158 -84.564147   APPROXIMATE  ChIJIZHO0CRGXogRI7Zjg5nFhxI  administrative_area_level_2,political          None                 Polk County, Tennessee                  1     OK
# 2                               Wayne County, TN, USA  35.282369 -87.776333   APPROXIMATE  ChIJ_Q2CuTbZfIgR-JtR_fSG8gc  administrative_area_level_2,political          None                Wayne County, Tennessee                  1     OK
# 3   Trousdale County, Hartsville/Trousdale County,...  36.396385 -86.154827   APPROXIMATE  ChIJv_juAUknZIgR9WMpJ3kXSw8  administrative_area_level_2,political          None            Trousdale County, Tennessee                  1     OK
# 4                             Bledsoe County, TN, USA  35.602886 -85.230841   APPROXIMATE  ChIJwy7Q1-ywYIgR7yiTP9k9SVo  administrative_area_level_2,political          None              Bledsoe County, Tennessee                  1     OK
# 5                             McNairy County, TN, USA  35.118321 -88.556531   APPROXIMATE  ChIJlQb3Pq7MfYgR1cM3x5uVE9c  administrative_area_level_2,political          None              McNairy County, Tennessee                  1     OK
# 82                            Chester County, TN, USA  35.427094 -88.672358   APPROXIMATE  ChIJHfamlak-fIgRfsAOD_E4tR0  administrative_area_level_2,political          None              Chester County, Tennessee                  1     OK
# 83                            Stewart County, TN, USA  36.502324 -87.776333   APPROXIMATE  ChIJH_USb_TgeogR_ZAp2Z30_w0  administrative_area_level_2,political          None              Stewart County, Tennessee                  1     OK
# 84                               Clay County, TN, USA  36.570177 -85.561210   APPROXIMATE  ChIJORJwEmYHZ4gRIG_C67qdzAY  administrative_area_level_2,political          None                 Clay County, Tennessee                  1     OK
# 85                             Carter County, TN, USA  36.263860 -82.127840   APPROXIMATE  ChIJ5wXSECiBUIgR7wUGQ3gZugk  administrative_area_level_2,political          None               Carter County, Tennessee                  1     OK
# 86                            Hawkins County, TN, USA  36.444555 -82.950156   APPROXIMATE  ChIJLwSnjGYAW4gRhZ6YFbz74nc  administrative_area_level_2,political          None              Hawkins County, Tennessee                  1     OK
# 87                             Blount County, TN, USA  35.671054 -83.847302   APPROXIMATE  ChIJlVR41UMbXIgRMzltQKV9-gw  administrative_area_level_2,political          None               Blount County, Tennessee                  1     OK
# 88                              Giles County, TN, USA  35.089475 -86.982429   APPROXIMATE  ChIJoc3Y_kkBY4gRTBBmck1uM4A  administrative_area_level_2,political          None                Giles County, Tennessee                  1     OK
# 89                             Morgan County, TN, USA  36.100428 -84.647912   APPROXIMATE  ChIJsf25DczsXYgRxZD9ROSK74k  administrative_area_level_2,political          None               Morgan County, Tennessee                  1     OK
# 90                             McMinn County, TN, USA  35.403705 -84.647912   APPROXIMATE  ChIJT5Yu-eU_XogRQAnU3e8XUyM  administrative_area_level_2,political          None               McMinn County, Tennessee                  1     OK
# 91                             Tipton County, TN, USA  35.521718 -89.737996   APPROXIMATE  ChIJSbqWEC9wf4gRv70EF_qHB-k  administrative_area_level_2,political          None               Tipton County, Tennessee                  1     OK
# 92                           Grainger County, TN, USA  36.305933 -83.549657   APPROXIMATE  ChIJybpboj6IW4gRJAtiBwCynhw  administrative_area_level_2,political          None             Grainger County, Tennessee                  1     OK
# 93                            Hamblen County, TN, USA  36.205433 -83.293409   APPROXIMATE  ChIJu1mNSsiYW4gRGhrKlGVN3tQ  administrative_area_level_2,political          None              Hamblen County, Tennessee                  1     OK
# 94                          Henderson County, TN, USA  35.642724 -88.401604   APPROXIMATE  ChIJf-CcMLdyfIgRRO4LXQOrBKI  administrative_area_level_2,political          None            Henderson County, Tennessee                  1     OK

# %%
county_center = pd.DataFrame(results)[['latitude', 'longitude', 'input_string']]

# %%
county_center['input_string'] = [x.split(' ')[0] for x in county_center['input_string']]

# %%
county_center.columns = ['lat', 'long', 'county']

# %%
county_center.head()
# Out:
#          lat       long     county
# 0  35.479252 -86.781852   Marshall
# 1  35.137158 -84.564147       Polk
# 2  35.282369 -87.776333      Wayne
# 3  36.396385 -86.154827  Trousdale
# 4  35.602886 -85.230841    Bledsoe

# %%
#county_center.to_csv('county_centers.csv')
